# %%
import os
from tqdm import tqdm
import numpy as np

from pyfstat import GlitchWriter, Writer
from pyfstat.utils import get_sft_as_arrays
import matplotlib.pyplot as plt
from matplotlib import colors

# %matplotlib inline

plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = 20


def normalize_array_with_nan(arr):
    """
    Normalizes a 2D array while ignoring NaN values.
    
    Parameters:
    arr (np.ndarray): Input 2D array with shape (m, n)
    
    Returns:
    np.ndarray: Normalized array with NaN values preserved
    """
    # Compute mean and standard deviation, ignoring NaN values
    max = np.nanmax(arr)
    min = np.nanmin(arr)
    
    # Normalize the array, keeping NaN values as they are
    normalized_arr = (arr - min)/(max-min)
    
    return normalized_arr

def plot_spectrograms(timestamps, frequency, fourier_data):
    fig, axs = plt.subplots(1, 1, figsize=(16, 10))
    axs = [axs]
    for ax in axs:
        ax.set(xlabel="Days", ylabel="Frequency [Hz]")

    time_in_days = (timestamps - timestamps[0]) / 86400

    axs[0].set_title("H1")
    c = axs[0].pcolormesh(
        time_in_days,
        frequency,
        fourier_data,
        norm=colors.CenteredNorm(),
    )
    fig.colorbar(c, ax=axs[0], orientation="horizontal", label="Fourier Amplitude")
    return fig, axs



label = "test"
outdir = os.path.join("testdata", label)
# Out:
# 25-08-19 23:20:46.790 pyfstat INFO    : Running PyFstat version 2.2.1+3.6fbce518.dirty
# /home/hoitim.cheung/.conda/envs/glitch/lib/python3.10/site-packages/PyFstat-2.2.1+3.6fbce518.dirty-py3.10.egg/pyfstat/core.py:13: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal
# 25-08-19 23:20:50.030 pyfstat.utils.importing INFO    : No $DISPLAY environment variable found, so importing matplotlib.pyplot with non-interactive 'Agg' backend.

# %%
ts = 1368970000
Tday = 150
timestamps, fourier_data = [], []
for i in tqdm(range(48*Tday)):
    tstart = ts + i * 1800
    frequency, _timestamps, _fourier_data = get_sft_as_arrays('sft2/simCW0/H-1_H1_1800SFT_simCW0-{}-1800.sft'.format(tstart))
    idx = np.where((frequency<100.05)*(frequency>99.9))[0]
    
    frequency = frequency[idx]
    timestamps.append(_timestamps['H1'])
    fourier_data.append(_fourier_data['H1'][idx])
# Out:
#   0%|          | 0/7200 [00:00<?, ?it/s]
# 25-08-19 23:27:21.779 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:27:21.823 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:27:21.869 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
#   0%|          | 3/7200 [00:00<05:10, 23.21it/s]
# 25-08-19 23:27:21.908 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:27:21.952 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:27:22.004 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
#   0%|          | 6/7200 [00:00<05:22, 22.28it/s]
# 25-08-19 23:27:22.047 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:27:22.091 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:27:22.141 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
#   0%|          | 9/7200 [00:00<05:12, 23.04it/s]
# 25-08-19 23:27:22.172 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:27:22.219 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:27:22.255 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
#
pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:48.104 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
#  99%|█████████▉| 7137/7200 [05:26<00:02, 22.05it/s]
# 25-08-19 23:32:48.152 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:48.204 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:48.254 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
#  99%|█████████▉| 7140/7200 [05:26<00:02, 21.55it/s]
# 25-08-19 23:32:48.299 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:48.336 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:48.384 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
#  99%|█████████▉| 7143/7200 [05:26<00:02, 21.83it/s]
# 25-08-19 23:32:48.432 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:48.469 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:48.512 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
#  99%|█████████▉| 7146/7200 [05:26<00:02, 22.49it/s]
# 25-08-19 23:32:48.556 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:48.605 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:48.649 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
#  99%|█████████▉| 7149/7200 [05:26<00:02, 22.51it/s]
# 25-08-19 23:32:48.689 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:48.743 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:48.787 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
#  99%|█████████▉| 7152/7200 [05:27<00:02, 22.09it/s]
# 25-08-19 23:32:48.831 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:48.880 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:48.917 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
#  99%|█████████▉| 7155/7200 [05:27<00:02, 21.90it/s]
# 25-08-19 23:32:48.970 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:49.010 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:49.060 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
#  99%|█████████▉| 7158/7200 [05:27<00:01, 22.82it/s]
# 25-08-19 23:32:49.089 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:49.142 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:49.179 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
#  99%|█████████▉| 7161/7200 [05:27<00:01, 22.26it/s]
# 25-08-19 23:32:49.232 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:49.274 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:49.321 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 100%|█████████▉| 7164/7200 [05:27<00:01, 22.31it/s]
# 25-08-19 23:32:49.365 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:49.409 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:49.454 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 100%|█████████▉| 7167/7200 [05:27<00:01, 23.00it/s]
# 25-08-19 23:32:49.486 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:49.533 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:49.581 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 100%|█████████▉| 7170/7200 [05:27<00:01, 22.59it/s]
# 25-08-19 23:32:49.625 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:49.673 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:49.719 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 100%|█████████▉| 7173/7200 [05:27<00:01, 22.23it/s]
# 25-08-19 23:32:49.765 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:49.812 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:49.860 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 100%|█████████▉| 7176/7200 [05:28<00:01, 21.98it/s]
# 25-08-19 23:32:49.905 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:49.950 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:49.995 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 100%|█████████▉| 7179/7200 [05:28<00:00, 21.97it/s]
# 25-08-19 23:32:50.041 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:50.088 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:50.123 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 100%|█████████▉| 7182/7200 [05:28<00:00, 22.40it/s]
# 25-08-19 23:32:50.169 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:50.217 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:50.264 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 100%|█████████▉| 7185/7200 [05:28<00:00, 21.89it/s]
# 25-08-19 23:32:50.314 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:50.361 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:50.405 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 100%|█████████▉| 7188/7200 [05:28<00:00, 21.72it/s]
# 25-08-19 23:32:50.454 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:50.507 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:50.553 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 100%|█████████▉| 7191/7200 [05:28<00:00, 21.43it/s]
# 25-08-19 23:32:50.598 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:50.644 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:50.687 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 100%|█████████▉| 7194/7200 [05:28<00:00, 21.61it/s]
# 25-08-19 23:32:50.735 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:50.785 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:50.834 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 100%|█████████▉| 7197/7200 [05:29<00:00, 21.20it/s]
# 25-08-19 23:32:50.883 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:50.931 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 25-08-19 23:32:50.979 pyfstat.utils.sft INFO    : Loading 1 SFTs from H1...
# 100%|██████████| 7200/7200 [05:29<00:00, 21.87it/s]

# %%
timestamps = np.concatenate(timestamps)

# %%
fourier_data = np.concatenate(fourier_data,axis=1)

# %%
data1 = fourier_data.real ** 2 + fourier_data.imag ** 2

fig, ax = plot_spectrograms(
    timestamps, frequency, data1,
);

# %%
idx = np.where((frequency<20.2)*(frequency>19.9))[0]
data1 = fourier_data.real ** 2 + fourier_data.imag ** 2

fig, ax = plot_spectrograms(
    timestamps, frequency[idx], data1[idx],
);
